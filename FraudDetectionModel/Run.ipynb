# %%
import subprocess
import sys

subprocess.Popen([sys.executable, '-m', 'streamlit', 'run', 'app.py'])
# Out:
# <Popen: returncode: None args: ['C:\\ProgramData\\anaconda3\\python.exe', '-...>

# %%
import streamlit
print(streamlit.__version__)
# Out:
# 1.51.0

# %%
import subprocess
import sys
import os

# Get the path to streamlit executable directly
streamlit_path = os.path.join(os.path.dirname(sys.executable), 'streamlit.exe')
print(f"Streamlit path: {streamlit_path}")
print(f"app.py exists : {os.path.exists('app.py')}")

subprocess.Popen([streamlit_path, 'run', 'app.py'])
print("Streamlit launched! Open http://localhost:8501 in your browser")
# Out:
# Streamlit path: C:\ProgramData\anaconda3\streamlit.exe
# app.py exists : True
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 10
#       7 print(f"Streamlit path: {streamlit_path}")
#       8 print(f"app.py exists : {os.path.exists('app.py')}")
# ---> 10 subprocess.Popen([streamlit_path, 'run', 'app.py'])
#      11 print("Streamlit launched! Open http://localhost:8501 in your browser")
#
# File C:\ProgramData\anaconda3\Lib\subprocess.py:1039, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1035         if self.text_mode:
#    1036             self.stderr = io.TextIOWrapper(self.stderr,
# ...
